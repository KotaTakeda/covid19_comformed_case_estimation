# %%
# %matplotlib nbagg
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as anim
import pandas as pd

# %%
# サイトからスクレイピング

# %%
# 配列を作る

# %%
# class TopTenAnimation:
#     '''
#     Args:
#         data_series: 2dimensional ndarray;
#             time series of data
#     '''
#     def __init__(self, data_series):
#         self.data_series = data_series
        
#     def increment_time(self, i):
        
# #     def animate(self, i)

# %%
# データセットを作成
data_series = np.zeros((26, time))
for t in range(1, time):
    data_series[:, t] = data_series[:, t-1] + np.random.rand(26)
    
alphabets = [chr(i) for i in range(65, 65+26)] # index

time_columns = [f't = {t}'for  t in range(time)] # columns

df = pd.DataFrame(data_series, columns=time_columns, index=alphabets)

# %%
# アニメーション
fig, ax = plt.subplots()
    
def animate(i):
    plt.cla()
    
#　配列を更新
    top_ten = df.sort_values(f't = {i}')[-10:]
    z = top_ten[f't = {i}']
    x = top_ten.index
    
    plt.title('t={}'.format(i))
    
# 描画
    ax.barh(x, z)
    
ani = anim.FuncAnimation(fig, animate, frames=100, interval = 100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
